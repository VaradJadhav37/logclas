# %%
import pandas as pd
df=pd.read_csv('dataset/synthetic_logs.csv')
df.head()
# Out:
#              timestamp           source  \
# 0  2025-06-27 07:20:25        ModernCRM
# 1      1/14/2025 23:07        ModernCRM
# 2       1/17/2025 1:29  AnalyticsEngine
# 3  2025-07-12 00:24:16         ModernHR
# 4  2025-06-02 18:25:23    BillingSystem
#
#                                          log_message    target_label  \
# 0  nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1     Email service experiencing issues with sending  Critical Error
# 2          Unauthorized access to data was attempted  Security Alert
# 3  nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4  nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
#
#   complexity
# 0       bert
# 1       bert
# 2       bert
# 3       bert
# 4       bert

# %%
df.drop(columns='complexity',inplace=True)

# %%
df.head()
# Out:
#              timestamp           source  \
# 0  2025-06-27 07:20:25        ModernCRM
# 1      1/14/2025 23:07        ModernCRM
# 2       1/17/2025 1:29  AnalyticsEngine
# 3  2025-07-12 00:24:16         ModernHR
# 4  2025-06-02 18:25:23    BillingSystem
#
#                                          log_message    target_label
# 0  nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1     Email service experiencing issues with sending  Critical Error
# 2          Unauthorized access to data was attempted  Security Alert
# 3  nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4  nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status

# %%
df.target_label.unique()
# Out:
# array(['HTTP Status', 'Critical Error', 'Security Alert', 'Error',
#        'System Notification', 'Resource Usage', 'User Action',
#        'Workflow Error', 'Deprecation Warning'], dtype=object)

# %%
#now we create a dbscan algorithm to cluster the logs based on their semantic similarity
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(df['log_message'].tolist())
from sklearn.cluster import DBSCAN
clustering = DBSCAN(eps=0.2, min_samples=1).fit(embeddings)
df['cluster'] = clustering.labels_
df.head()
# Out:
#              timestamp           source  \
# 0  2025-06-27 07:20:25        ModernCRM
# 1      1/14/2025 23:07        ModernCRM
# 2       1/17/2025 1:29  AnalyticsEngine
# 3  2025-07-12 00:24:16         ModernHR
# 4  2025-06-02 18:25:23    BillingSystem
#
#                                          log_message    target_label  cluster
# 0  nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status        0
# 1     Email service experiencing issues with sending  Critical Error        1
# 2          Unauthorized access to data was attempted  Security Alert        2
# 3  nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status        0
# 4  nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status        3

# %%
embeddings[:3].shape
# Out:
# (3, 384)

# %%
df[df['cluster']==10]
# Out:
#          timestamp         source  \
# 13  8/4/2025 19:57  ThirdPartyAPI
#
#                                           log_message    target_label  cluster
# 13  Multiple bad login attempts detected on user 8...  Security Alert       10

# %%
#now we sort the clusters based on their size to identify the most common log patterns
cluster_counts = df['cluster'].value_counts().reset_index()
cluster_counts.columns = ['cluster', 'count']
cluster_counts.head(20)
# Out:
#     cluster  count
# 0         0    406
# 1         4    159
# 2         3    143
# 3        12     60
# 4        50     57
# 5        67     52
# 6        58     51
# 7        46     44
# 8        14     40
# 9        19     33
# 10       96     21
# 11       39     21
# 12       27     21
# 13      127     20
# 14       16     19
# 15       68     19
# 16        7     19
# 17       80     19
# 18       25     18
# 19       84     15

# %%
#print log messages where clusters greater than 10
for cluster_id in cluster_counts[cluster_counts['count']>10]['cluster']:
    print(f"Cluster {cluster_id}:")
    print(df[df['cluster']==cluster_id]['log_message'].tolist())
    print("\n")
# Out:
# Cluster 0:
# ...

# %%
import re
def classify_with_regex(log_message):
    regex_patterns = {
        r"User User\d+ logged (in|out).": "User Action",
        r"Backup (started|ended) at .*": "System Notification",
        r"Backup completed successfully.": "System Notification",
        r"System updated to version .*": "System Notification",
        r"File .* uploaded successfully by user .*": "System Notification",
        r"Disk cleanup completed successfully.": "System Notification",
        r"System reboot initiated by user .*": "System Notification",
        r"Account with ID .* created by .*": "User Action"
    }
    for pattern, label in regex_patterns.items():
        if re.search(pattern, log_message):
            return label
    return None

# %%
df['regex_label'] = df['log_message'].apply(classify_with_regex)
df.head(20)
# Out:
#               timestamp           source  \
# 0   2025-06-27 07:20:25        ModernCRM
# 1       1/14/2025 23:07        ModernCRM
# 2        1/17/2025 1:29  AnalyticsEngine
# 3   2025-07-12 00:24:16         ModernHR
# 4   2025-06-02 18:25:23    BillingSystem
# 5   2025-10-09 10:30:31         ModernHR
# 6        3/1/2025 19:14         ModernHR
# 7       10/11/2025 8:44         ModernHR
# 8   2025-02-12 10:42:29    ThirdPartyAPI
# 9   2025-03-30 04:01:45         ModernHR
# 10       8/9/2025 18:58        ModernCRM
# 11      6/15/2025 11:44         ModernHR
# 12  2025-07-12 03:03:18         ModernHR
# 13       8/4/2025 19:57    ThirdPartyAPI
# 14        1/4/2025 1:43    ThirdPartyAPI
# 15        5/1/2025 9:41        ModernCRM
# 16  2025-11-15 14:48:30    BillingSystem
# 17  2025-01-27 12:39:05        ModernCRM
# 18      2/22/2025 17:49        ModernCRM
# 19  2025-07-10 01:17:59    BillingSystem
#
#                                           log_message         target_label  \
# ...

# %%
df[df['regex_label'].isnull()]
# Out:
#                 timestamp           source  \
# 0     2025-06-27 07:20:25        ModernCRM
# 1         1/14/2025 23:07        ModernCRM
# 2          1/17/2025 1:29  AnalyticsEngine
# 3     2025-07-12 00:24:16         ModernHR
# 4     2025-06-02 18:25:23    BillingSystem
# ...                   ...              ...
# 2405  2025-08-13 07:29:25         ModernHR
# 2406       1/11/2025 5:32         ModernHR
# 2407  2025-08-03 03:07:47    ThirdPartyAPI
# 2408     11/11/2025 11:52    BillingSystem
# 2409     12/25/2025 13:21  AnalyticsEngine
#
#                                             log_message    target_label  \
# 0     nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1        Email service experiencing issues with sending  Critical Error
# 2             Unauthorized access to data was attempted  Security Alert
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4     nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
# ...

# %%
df_non_regex = df[df['regex_label'].isnull()].copy()
df_non_legacy = df_non_regex[df_non_regex['target_label'] != 'LegacyCRM'].copy()

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')  # Lightweight embedding model
embeddings_filtered = model.encode(df_non_legacy['log_message'].tolist())


X = embeddings_filtered
y = df_non_legacy['target_label'].values

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#                 precision    recall  f1-score   support
#
# Critical Error       0.98      1.00      0.99        52
#          Error       0.98      0.98      0.98        47
#    HTTP Status       1.00      1.00      1.00       316
# Resource Usage       1.00      1.00      1.00        50
# Security Alert       0.99      0.99      0.99       107
# Workflow Error       0.00      0.00      0.00         1
#
#       accuracy                           0.99       573
#      macro avg       0.83      0.83      0.83       573
#   weighted avg       0.99      0.99      0.99       573
# c:\Users\Varad\logclas\log\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')  # Lightweight embedding model
embeddings_filtered = model.encode(df_non_regex['log_message'].tolist())


X = embeddings_filtered
y = df_non_legacy['target_label'].values

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#                 precision    recall  f1-score   support
#
# Critical Error       0.98      1.00      0.99        52
#          Error       0.98      0.98      0.98        47
#    HTTP Status       1.00      1.00      1.00       316
# Resource Usage       1.00      1.00      1.00        50
# Security Alert       0.99      0.99      0.99       107
# Workflow Error       0.00      0.00      0.00         1
#
#       accuracy                           0.99       573
#      macro avg       0.83      0.83      0.83       573
#   weighted avg       0.99      0.99      0.99       573
# c:\Users\Varad\logclas\log\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
import joblib
joblib.dump(clf,'../models/log_classifier_model.joblib')
# Out:
# ['../models/log_classifier_model.joblib']
